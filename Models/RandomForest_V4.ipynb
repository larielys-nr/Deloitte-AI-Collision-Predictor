# %%
import numpy as np
import pandas as pd
import os

# %%
collision_train = pd.read_csv("train_data-Dell.csv")
#collision_train.info()
#collision_train.head()

# %%
collision_test = pd.read_csv("test_data-Dell.csv")
#collision_test.info()
#collision_test.head()

# %% [markdown]
# Dummy encoding converts a variable that has n possible distinct values, into n-1 binary variables.
#
# For regression-type problems Dummy Encoding is preferable as we wish to avoid perfect collinearity between the binary variables that are being generated by the encoding. In the classification problem however, we are not concerned about inflating factors and hence can choose either of the two schemes. They will produce equivalent encodings.
#
# By default pd.get_dummies() does one-hot enocoding. To do dummy encoding, you need to pass the parameter drop_first=True.

# %%
categorical_columns = collision_train.select_dtypes(include=['object']).columns

#print("Categorical columns train:")
#print(categorical_columns)

#test
categorical_columns_test = collision_test.select_dtypes(include=['object']).columns

#print("Categorical columns test:")
#print(categorical_columns_test)

# %%
# Copy the DataFrame to avoid chained assignment issues
collision_train_copy = collision_train.copy()

# Drop rows with any NaN values
collision_train_copy.dropna(inplace=True)

# Replace missing values in 'c_object_type' column with the mode of non-NaN values
mode_c_object_type = collision_train_copy['c_object_type'].mode()[0]  # Get the mode value
collision_train_copy['c_object_type'].fillna(mode_c_object_type, inplace=True)

# Creating dummy variables
dummy_columns = pd.get_dummies(collision_train_copy['c_object_type'], prefix='c_object_type')

# Concatenating the original DataFrame with the dummy variables
new_collision_train = pd.concat([collision_train_copy, dummy_columns], axis=1)

# Dropping the original 'c_object_type' column
new_collision_train.drop('c_object_type', axis=1, inplace=True)

# Displaying the new DataFrame
print(new_collision_train)
# Out:
#        event_id  time_to_tca  mission_id       risk  max_risk_estimate  \
# 5             1     6.530455           5  -7.561299          -7.254301
# 6             1     5.561646           5  -9.315693          -7.468904
# 7             1     5.226504           5  -7.422508          -7.051001
# 8             1     3.570013           5  -9.248105          -7.327533
# 29            3     6.950088          19  -9.568315          -7.057793
# ...         ...          ...         ...        ...                ...
# 70096      5638     1.441664           2 -30.000000          -5.937042
# 70097      5638     1.259823           2 -30.000000          -5.936667
# 70098      5638     0.852358           2 -30.000000          -5.936667
# 70099      5638     0.512948           2 -30.000000          -5.934047
# 70100      5638     0.228585           2 -30.000000          -6.259953
#
#        max_risk_scaling  miss_distance  relative_speed  relative_position_r  \
# 5              2.746782         2392.0          3434.0                 74.3
# 6              7.223137         3587.0          3434.0                 99.0
# 7              2.956639         7882.0          3434.0                -50.0
# 8              7.425994        26899.0          3434.0                -82.0
# 29             8.965371        29654.0         13574.0                 19.2
# ...                 ...            ...             ...                  ...
# 70096        729.033039        11045.0          2223.0                -86.0
# 70097        729.043855        11046.0          2223.0                -85.0
# 70098        727.994794        11050.0          2223.0                -86.6
# 70099        721.452831        11043.0          2223.0                -87.3
# 70100       3355.226276        10964.0          2223.0                -83.9
#
#        relative_position_t  ...  t_sigma_ndot  c_sigma_ndot   F10   F3M   SSN  \
# 5                   2317.1  ...      0.004199      0.047385  71.0  88.0   0.0
# 6                   3475.4  ...      0.003725      0.040020  70.0  87.0  13.0
# 7                  -7638.3  ...      0.003588      0.083247  70.0  87.0  13.0
# 8                 -26067.0  ...      0.003408      0.058311  71.0  87.0  21.0
# 29                 12494.9  ...      0.010349      0.367497  68.0  70.0   0.0
# ...                    ...  ...           ...           ...   ...   ...   ...
# 70096              10933.4  ...      0.003790      0.028745  68.0  72.0   0.0
# 70097              10934.8  ...      0.003644      0.028745  68.0  72.0   0.0
# 70098              10938.0  ...      0.003680      0.028745  68.0  72.0   0.0
# 70099              10931.9  ...      0.003744      0.028745  68.0  72.0   0.0
# 70100              10853.7  ...      0.003772      0.027305  68.0  72.0   0.0
#
#          AP  c_object_type_DEBRIS  c_object_type_PAYLOAD  \
# 5       2.0                  True                  False
# 6      14.0                  True                  False
# 7      14.0                  True                  False
# 8       5.0                  True                  False
# 29     18.0                  True                  False
# ...     ...                   ...                    ...
# 70096   5.0                  True                  False
# 70097   5.0                  True                  False
# 70098   5.0                  True                  False
# 70099  10.0                  True                  False
# 70100  10.0                  True                  False
#
#        c_object_type_ROCKET BODY  c_object_type_TBA
# 5                          False              False
# 6                          False              False
# 7                          False              False
# 8                          False              False
# 29                         False              False
# ...                          ...                ...
# 70096                      False              False
# 70097                      False              False
# 70098                      False              False
# 70099                      False              False
# 70100                      False              False
#
# [42515 rows x 106 columns]
# /tmp/ipykernel_60394/2765172438.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   collision_train_copy['c_object_type'].fillna(mode_c_object_type, inplace=True)

# %%
# Repeat the same process for the test
# Copy the DataFrame to avoid chained assignment issues
collision_test_copy = collision_test.copy()

# Drop rows with any NaN values
collision_test_copy.dropna(inplace=True)

# Replace missing values in 'c_object_type' column with the mode of non-NaN values
mode_c_object_type_test = collision_test_copy['c_object_type'].mode()[0]  # Get the mode value
collision_test_copy['c_object_type'].fillna(mode_c_object_type_test, inplace=True)

# Creating dummy variables
dummy_columns_test = pd.get_dummies(collision_test_copy['c_object_type'], prefix='c_object_type')

# Concatenating the original DataFrame with the dummy variables
new_collision_test = pd.concat([collision_test_copy, dummy_columns_test], axis=1)

# Dropping the original 'c_object_type' column
new_collision_test.drop('c_object_type', axis=1, inplace=True)

# Displaying the new DataFrame
print(new_collision_test)
# Out:
#        event_id  time_to_tca  mission_id       risk  max_risk_estimate  \
# 37            4     6.702359           5 -30.000000          -6.957818
# 38            4     6.351916           5  -6.657380          -6.283746
# 39            4     6.038843           5  -6.884722          -6.387534
# 40            4     5.705221           5  -6.868061          -6.378408
# 41            4     5.038975           5  -9.558462          -6.828566
# ...         ...          ...         ...        ...                ...
# 24464      2165     3.596498           2 -14.871278          -6.488518
# 24465      2165     3.290859           2 -13.675101          -6.458296
# 24466      2165     2.950547           2 -13.856673          -6.463442
# 24467      2165     2.570998           2 -13.486516          -6.450629
# 24468      2165     2.263915           2 -13.484391          -6.450751
#
#        max_risk_scaling  miss_distance  relative_speed  relative_position_r  \
# 37            88.002734        11122.0         14324.0                -87.2
# 38             2.922384        12180.0         14324.0                -82.5
# 39             3.362820        14575.0         14324.0                -86.6
# 40             3.331973        14283.0         14324.0                -84.5
# 41             9.541551        21920.0         14324.0               -159.5
# ...                 ...            ...             ...                  ...
# 24464         23.466469        14955.0         10774.0               -493.3
# 24465         20.653985        13362.0         10774.0               -499.1
# 24466         21.080822        13582.0         10774.0               -499.6
# 24467         20.215701        13218.0         10774.0               -496.1
# 24468         20.210637        13235.0         10774.0               -495.0
#
#        relative_position_t  ...  t_sigma_ndot  c_sigma_ndot    F10   F3M  \
# 37                  3465.3  ...      0.004019      0.037594   71.0  75.0
# 38                  3791.9  ...      0.004062      0.037953   72.0  75.0
# 39                  4536.4  ...      0.004093      0.038018   72.0  75.0
# 40                  4447.6  ...      0.003932      0.038010   72.0  75.0
# 41                  6820.7  ...      0.003841      0.035362   72.0  75.0
# ...                    ...  ...           ...           ...    ...   ...
# 24464             -10327.7  ...      0.004603      0.068380  108.0  92.0
# 24465              -9227.1  ...      0.004266      0.068378  102.0  92.0
# 24466              -9378.0  ...      0.004025      0.068378  102.0  92.0
# 24467              -9126.3  ...      0.004192      0.068378  103.0  92.0
# 24468              -9141.5  ...      0.004277      0.068378  103.0  92.0
#
#         SSN    AP  c_object_type_DEBRIS  c_object_type_PAYLOAD  \
# 37     13.0  24.0                  True                  False
# 38     14.0  24.0                  True                  False
# 39     14.0  24.0                  True                  False
# 40     14.0  24.0                  True                  False
# 41     14.0   9.0                  True                  False
# ...     ...   ...                   ...                    ...
# 24464  87.0  13.0                  True                  False
# 24465  55.0  12.0                  True                  False
# 24466  55.0  12.0                  True                  False
# 24467  38.0  12.0                  True                  False
# 24468  38.0  12.0                  True                  False
#
#        c_object_type_ROCKET BODY  c_object_type_TBA
# 37                         False              False
# 38                         False              False
# 39                         False              False
# 40                         False              False
# 41                         False              False
# ...                          ...                ...
# 24464                      False              False
# 24465                      False              False
# 24466                      False              False
# 24467                      False              False
# 24468                      False              False
#
# [15222 rows x 106 columns]
# /tmp/ipykernel_60394/1434563843.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   collision_test_copy['c_object_type'].fillna(mode_c_object_type_test, inplace=True)

# %%
#transform data to proper scale for train
from sklearn.preprocessing import MinMaxScaler

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the data
new_collision_train_scaled = scaler.fit_transform(new_collision_train)

# Convert the scaled data back to a DataFrame
new_collision_train_scaled = pd.DataFrame(new_collision_train_scaled, columns=new_collision_train.columns)

# %%
#option for test
new_collision_test_scaled = scaler.transform(new_collision_test)

new_collision_test_scaled = pd.DataFrame(new_collision_test_scaled, columns=new_collision_test.columns)

# %%
X_train = new_collision_train_scaled.drop(columns=['time_to_tca']).values
y_train = new_collision_train_scaled['time_to_tca'].values

# %%
from sklearn.ensemble import RandomForestRegressor

#Number of trees in random forest
#n_estimators = [int(x) for x in np.linspace(start = 10, stop = 40, num = 10)]
n_estimators = [20,40,60,80]
# Maximum number of levels in tree
max_depth = [2,4]
# Minimum number of samples required to split a node
min_samples_split = [2, 5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
# Create the param grid
param_grid = {'n_estimators': n_estimators,
               
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
print(param_grid)
# Out:
# {'n_estimators': [20, 40, 60, 80], 'max_depth': [2, 4], 'min_samples_split': [2, 5], 'min_samples_leaf': [1, 2], 'bootstrap': [True, False]}

# %%
regressor = RandomForestRegressor()

# %%
from sklearn.model_selection import GridSearchCV
rf_Grid = GridSearchCV(estimator = regressor, param_grid = param_grid, cv = 3, verbose=2)

# %%
rf_Grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 64 candidates, totalling 192 fits
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   5.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   5.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   5.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  11.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  11.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  11.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time=  17.4s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time=  17.5s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time=  17.4s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=  23.2s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=  23.4s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=  23.3s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   5.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   5.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   5.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  11.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  11.7s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  11.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time=  17.5s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time=  17.5s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time=  17.5s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=  23.3s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=  23.2s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=  23.4s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   5.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   5.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   5.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  11.7s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  11.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  11.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time=  17.4s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time=  17.4s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time=  17.7s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=  23.4s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=  23.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=  23.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=20; total time=   5.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=20; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=20; total time=   5.9s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=40; total time=  11.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=40; total time=  11.7s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=40; total time=  11.7s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=60; total time=  17.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=60; total time=  17.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=60; total time=  17.9s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=  23.5s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=  23.3s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=  23.7s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=  10.9s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=  10.9s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=  10.9s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  22.0s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  22.1s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  21.8s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time=  32.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time=  32.8s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time=  32.7s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=  43.9s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=  43.9s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=  43.8s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=  10.9s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=  10.9s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=  10.9s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  21.7s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  21.9s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  21.8s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time=  32.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time=  32.8s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time=  32.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=  43.4s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=  43.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=  43.8s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=  10.9s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=  10.9s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=  10.9s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  21.7s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  21.8s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  21.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time=  32.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time=  32.5s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time=  32.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=  43.9s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=  43.8s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=  44.3s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=20; total time=  11.0s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=20; total time=  11.1s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=20; total time=  11.1s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=40; total time=  22.0s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=40; total time=  21.8s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=40; total time=  22.0s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=60; total time=  33.1s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=60; total time=  32.9s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=60; total time=  32.7s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=  44.0s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=  44.2s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=  44.3s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   9.6s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   9.6s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   9.6s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  18.9s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  18.9s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  18.9s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time=  28.5s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time=  28.3s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time=  28.4s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=  38.1s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=  38.3s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=  38.6s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   9.6s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   9.7s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   9.6s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  19.3s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  19.4s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  19.3s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time=  28.4s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time=  28.9s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time=  28.7s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=  38.3s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=  37.9s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=  38.0s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   9.5s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   9.6s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=   9.4s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  18.8s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  18.8s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  18.9s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time=  28.2s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time=  28.3s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time=  28.3s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=  37.8s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=  38.5s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=  38.8s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=20; total time=   9.7s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=20; total time=   9.6s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=20; total time=   9.6s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=40; total time=  19.0s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=40; total time=  18.9s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=40; total time=  18.8s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=60; total time=  28.4s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=60; total time=  28.2s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=60; total time=  28.3s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=  37.5s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=  38.0s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=  38.1s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=  17.7s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=  17.6s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=  17.8s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  35.3s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  35.3s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  35.3s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time=  53.1s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time=  53.4s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time=  53.8s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time= 1.2min
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time= 1.2min
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time= 1.2min
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=  17.6s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=  17.6s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=  17.7s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  35.5s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  35.4s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  35.2s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time=  53.0s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time=  53.0s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time=  52.9s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time= 1.2min
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time= 1.2min
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time= 1.2min
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=  17.7s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=  17.7s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=  18.0s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  36.1s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  36.3s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  35.5s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time=  53.6s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time=  55.5s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time=  54.6s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time= 1.2min
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time= 1.2min
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time= 1.2min
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=20; total time=  18.6s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=20; total time=  18.3s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=20; total time=  17.8s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=40; total time=  36.1s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=40; total time=  36.3s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=40; total time=  36.0s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=60; total time=  53.6s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=60; total time=  53.6s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=60; total time=  53.5s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time= 1.2min
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time= 1.2min
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time= 1.2min
# GridSearchCV(cv=3, estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True, False], 'max_depth': [2, 4],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [20, 40, 60, 80]},
#              verbose=2)

# %%
rf_Grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 4,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 80}

# %%
# Initialize the RandomForestRegressor with the best parameters
#best_estimator = rf_Grid.best_estimator_
regressor = RandomForestRegressor(bootstrap=True, max_depth=4, min_samples_leaf=2, 
                                   min_samples_split=2, n_estimators=80)

# Fit the model to your training data
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=4, min_samples_leaf=2, n_estimators=80)

# %%
X_test = new_collision_test_scaled.drop(columns=['time_to_tca']).values
y_test = new_collision_test_scaled['time_to_tca'].values

# %%
# Prediction on the testing dataset
# Prediction on the testing dataset
y_test_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
#Evaluating on test set

mae = mean_absolute_error(y_test, y_test_pred)
mse = mean_squared_error(y_test, y_test_pred)
r2 = r2_score(y_test, y_test_pred)
rmse = np.sqrt(mse)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R^2 Score:", r2)
# Out:
# Mean Absolute Error (MAE): 0.14888401978606702
# Mean Squared Error (MSE): 0.034034965367355244
# Root Mean Squared Error (RMSE): 0.18448567794643367
# R^2 Score: 0.15824102232090964

# %%
from sklearn.metrics import explained_variance_score
evs = explained_variance_score(y_test, y_test_pred)

print('The EVS of the test is: %.2f' % evs)
# Out:
# The EVS of the test is: 0.20

# %%
#Prediction on the training set

y_train_pred = regressor.predict(X_train)

mae = mean_absolute_error(y_train, y_train_pred)
mse = mean_squared_error(y_train, y_train_pred)
r2 = r2_score(y_train, y_train_pred)
rmse = np.sqrt(mse)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R^2 Score:", r2)
# Out:
# Mean Absolute Error (MAE): 0.13681312192614037
# Mean Squared Error (MSE): 0.03008379886569868
# Root Mean Squared Error (RMSE): 0.1734468185516779
# R^2 Score: 0.6240712906573175

# %%
from sklearn.metrics import explained_variance_score
evs = explained_variance_score(y_train, y_train_pred)

print('The EVS of the train is: %.2f' % evs)
# Out:
# The EVS of the train is: 0.62

# %%
# Create loop throuth x columns
feature_list = [f"feature_{i}" for i in range(X_train.shape[1])]

# Create a pandas Series with feature importances
feature_imp = pd.Series(regressor.feature_importances_, index=feature_list).sort_values(ascending = False)

print("List of important features:", feature_imp)
# Out:
# List of important features: feature_32     0.665639
# feature_62     0.121223
# feature_2      0.119675
# feature_76     0.029660
# feature_24     0.019725
#                  ...
# feature_35     0.000000
# feature_34     0.000000
# feature_33     0.000000
# feature_31     0.000000
# feature_104    0.000000
# Length: 105, dtype: float64

# %%
plt.rcParams['font.sans-serif'] = 'DejaVu Sans'

# %%
from yellowbrick.regressor import ResidualsPlot

# Instantiate the visualizer with the trained regressor model
visualizer = ResidualsPlot(regressor)

visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
visualizer.poof()
# Out:
# <Axes: title={'center': 'Residuals for RandomForestRegressor Model'}, xlabel='Predicted Value', ylabel='Residuals'>
