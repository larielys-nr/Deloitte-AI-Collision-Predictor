# %%
import numpy as np
import pandas as pd
import os
import joblib
from pathlib import Path

# %%
collision_train = pd.read_csv("train_data-Dell.csv")
#collision_train.info()
#collision_train.head()

# %%
collision_test = pd.read_csv("test_data-Dell.csv")
#collision_test.info()
#collision_test.head()

# %% [markdown]
# Dummy encoding converts a variable that has n possible distinct values, into n-1 binary variables.
#
# For regression-type problems Dummy Encoding is preferable as we wish to avoid perfect collinearity between the binary variables that are being generated by the encoding. In the classification problem however, we are not concerned about inflating factors and hence can choose either of the two schemes. They will produce equivalent encodings.
#
# By default pd.get_dummies() does one-hot enocoding. To do dummy encoding, you need to pass the parameter drop_first=True.

# %%
categorical_columns = collision_train.select_dtypes(include=['object']).columns

#print("Categorical columns train:")
#print(categorical_columns)

#test
categorical_columns_test = collision_test.select_dtypes(include=['object']).columns

#print("Categorical columns test:")
#print(categorical_columns_test)

# %%
# Copy the DataFrame to avoid chained assignment issues
collision_train_copy = collision_train.copy()

# Drop rows with any NaN values
collision_train_copy.dropna(inplace=True)

# Replace missing values in 'c_object_type' column with the mode of non-NaN values
mode_c_object_type = collision_train_copy['c_object_type'].mode()[0]  # Get the mode value
collision_train_copy['c_object_type'].fillna(mode_c_object_type, inplace=True)

# Creating dummy variables
dummy_columns = pd.get_dummies(collision_train_copy['c_object_type'], prefix='c_object_type')

# Concatenating the original DataFrame with the dummy variables
new_collision_train = pd.concat([collision_train_copy, dummy_columns], axis=1)

# Dropping the original 'c_object_type' column
new_collision_train.drop('c_object_type', axis=1, inplace=True)

# Displaying the new DataFrame
print(new_collision_train)
# Out:
#         event_id  time_to_tca  mission_id       risk  max_risk_estimate  \
# 5              1     6.530455           5  -7.561299          -7.254301
# 6              1     5.561646           5  -9.315693          -7.468904
# 7              1     5.226504           5  -7.422508          -7.051001
# 8              1     3.570013           5  -9.248105          -7.327533
# 29             3     6.950088          19  -9.568315          -7.057793
# ...          ...          ...         ...        ...                ...
# 162616     13152     1.484446          15 -30.000000          -7.111427
# 162617     13152     1.075997          15 -30.000000          -7.113679
# 162618     13152     0.677213          15 -30.000000          -7.114243
# 162619     13152     0.446067          15 -30.000000          -7.394264
# 162620     13152     0.144192          15 -30.000000          -7.394695
#
#         max_risk_scaling  miss_distance  relative_speed  relative_position_r  \
# 5               2.746782         2392.0          3434.0                 74.3
# 6               7.223137         3587.0          3434.0                 99.0
# 7               2.956639         7882.0          3434.0                -50.0
# 8               7.425994        26899.0          3434.0                -82.0
# 29              8.965371        29654.0         13574.0                 19.2
# ...                  ...            ...             ...                  ...
# 162616       1510.933859        24980.0          1156.0              -1158.4
# 162617       1536.096361        25023.0          1156.0              -1157.4
# 162618       1546.486178        25032.0          1156.0              -1157.6
# 162619      19867.782213        25214.0          1156.0              -1204.9
# 162620      19916.402793        25222.0          1156.0              -1204.7
#
#         relative_position_t  ...  t_sigma_ndot  c_sigma_ndot   F10   F3M  \
# 5                    2317.1  ...      0.004199      0.047385  71.0  88.0
# 6                    3475.4  ...      0.003725      0.040020  70.0  87.0
# 7                   -7638.3  ...      0.003588      0.083247  70.0  87.0
# 8                  -26067.0  ...      0.003408      0.058311  71.0  87.0
# 29                  12494.9  ...      0.010349      0.367497  68.0  70.0
# ...                     ...  ...           ...           ...   ...   ...
# 162616             -24911.2  ...      0.001573      0.102720  71.0  72.0
# 162617             -24954.3  ...      0.001511      0.102721  71.0  72.0
# 162618             -24963.0  ...      0.001703      0.102722  71.0  72.0
# 162619             -25143.6  ...      0.001678      0.058784  71.0  72.0
# 162620             -25151.7  ...      0.001653      0.058784  71.0  72.0
#
#          SSN    AP  c_object_type_DEBRIS  c_object_type_PAYLOAD  \
# 5        0.0   2.0                  True                  False
# 6       13.0  14.0                  True                  False
# 7       13.0  14.0                  True                  False
# 8       21.0   5.0                  True                  False
# 29       0.0  18.0                  True                  False
# ...      ...   ...                   ...                    ...
# 162616  16.0   1.0                  True                  False
# 162617  16.0   1.0                  True                  False
# 162618  16.0   1.0                  True                  False
# 162619  12.0   1.0                  True                  False
# 162620  12.0   1.0                  True                  False
#
#         c_object_type_ROCKET BODY  c_object_type_TBA
# 5                           False              False
# 6                           False              False
# 7                           False              False
# 8                           False              False
# 29                          False              False
# ...                           ...                ...
# 162616                      False              False
# 162617                      False              False
# 162618                      False              False
# 162619                      False              False
# 162620                      False              False
#
# [97450 rows x 106 columns]

# %%
# Repeat the same process for the test
# Copy the DataFrame to avoid chained assignment issues
collision_test_copy = collision_test.copy()

# Drop rows with any NaN values
collision_test_copy.dropna(inplace=True)

# Replace missing values in 'c_object_type' column with the mode of non-NaN values
mode_c_object_type_test = collision_test_copy['c_object_type'].mode()[0]  # Get the mode value
collision_test_copy['c_object_type'].fillna(mode_c_object_type_test, inplace=True)

# Creating dummy variables
dummy_columns_test = pd.get_dummies(collision_test_copy['c_object_type'], prefix='c_object_type')

# Concatenating the original DataFrame with the dummy variables
new_collision_test = pd.concat([collision_test_copy, dummy_columns_test], axis=1)

# Dropping the original 'c_object_type' column
new_collision_test.drop('c_object_type', axis=1, inplace=True)

# Displaying the new DataFrame
print(new_collision_test)
# Out:
#        event_id  time_to_tca  mission_id       risk  max_risk_estimate  \
# 37            4     6.702359           5 -30.000000          -6.957818
# 38            4     6.351916           5  -6.657380          -6.283746
# 39            4     6.038843           5  -6.884722          -6.387534
# 40            4     5.705221           5  -6.868061          -6.378408
# 41            4     5.038975           5  -9.558462          -6.828566
# ...         ...          ...         ...        ...                ...
# 24464      2165     3.596498           2 -14.871278          -6.488518
# 24465      2165     3.290859           2 -13.675101          -6.458296
# 24466      2165     2.950547           2 -13.856673          -6.463442
# 24467      2165     2.570998           2 -13.486516          -6.450629
# 24468      2165     2.263915           2 -13.484391          -6.450751
#
#        max_risk_scaling  miss_distance  relative_speed  relative_position_r  \
# 37            88.002734        11122.0         14324.0                -87.2
# 38             2.922384        12180.0         14324.0                -82.5
# 39             3.362820        14575.0         14324.0                -86.6
# 40             3.331973        14283.0         14324.0                -84.5
# 41             9.541551        21920.0         14324.0               -159.5
# ...                 ...            ...             ...                  ...
# 24464         23.466469        14955.0         10774.0               -493.3
# 24465         20.653985        13362.0         10774.0               -499.1
# 24466         21.080822        13582.0         10774.0               -499.6
# 24467         20.215701        13218.0         10774.0               -496.1
# 24468         20.210637        13235.0         10774.0               -495.0
#
#        relative_position_t  ...  t_sigma_ndot  c_sigma_ndot    F10   F3M  \
# 37                  3465.3  ...      0.004019      0.037594   71.0  75.0
# 38                  3791.9  ...      0.004062      0.037953   72.0  75.0
# 39                  4536.4  ...      0.004093      0.038018   72.0  75.0
# 40                  4447.6  ...      0.003932      0.038010   72.0  75.0
# 41                  6820.7  ...      0.003841      0.035362   72.0  75.0
# ...                    ...  ...           ...           ...    ...   ...
# 24464             -10327.7  ...      0.004603      0.068380  108.0  92.0
# 24465              -9227.1  ...      0.004266      0.068378  102.0  92.0
# 24466              -9378.0  ...      0.004025      0.068378  102.0  92.0
# 24467              -9126.3  ...      0.004192      0.068378  103.0  92.0
# 24468              -9141.5  ...      0.004277      0.068378  103.0  92.0
#
#         SSN    AP  c_object_type_DEBRIS  c_object_type_PAYLOAD  \
# 37     13.0  24.0                  True                  False
# 38     14.0  24.0                  True                  False
# 39     14.0  24.0                  True                  False
# 40     14.0  24.0                  True                  False
# 41     14.0   9.0                  True                  False
# ...     ...   ...                   ...                    ...
# 24464  87.0  13.0                  True                  False
# 24465  55.0  12.0                  True                  False
# 24466  55.0  12.0                  True                  False
# 24467  38.0  12.0                  True                  False
# 24468  38.0  12.0                  True                  False
#
#        c_object_type_ROCKET BODY  c_object_type_TBA
# 37                         False              False
# 38                         False              False
# 39                         False              False
# 40                         False              False
# 41                         False              False
# ...                          ...                ...
# 24464                      False              False
# 24465                      False              False
# 24466                      False              False
# 24467                      False              False
# 24468                      False              False
#
# [15222 rows x 106 columns]

# %%
#transform data to proper scale for train
from sklearn.preprocessing import MinMaxScaler

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the data
new_collision_train_scaled = scaler.fit_transform(new_collision_train)

# Convert the scaled data back to a DataFrame
new_collision_train_scaled = pd.DataFrame(new_collision_train_scaled, columns=new_collision_train.columns)

# %%
#option for test
new_collision_test_scaled = scaler.transform(new_collision_test)

new_collision_test_scaled = pd.DataFrame(new_collision_test_scaled, columns=new_collision_test.columns)

# %%
X_train = new_collision_train_scaled.drop(columns=['time_to_tca']).values
y_train = new_collision_train_scaled['time_to_tca'].values

# %%
from sklearn.ensemble import RandomForestRegressor

#Number of trees in random forest
#n_estimators = [int(x) for x in np.linspace(start = 10, stop = 40, num = 10)]
n_estimators = [20,40,60,80]
# Maximum number of levels in tree
max_depth = [2,4]
# Minimum number of samples required to split a node
min_samples_split = [2, 5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
# Create the param grid
param_grid = {'n_estimators': n_estimators,
               
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
print(param_grid)
# Out:
# {'n_estimators': [20, 40, 60, 80], 'max_depth': [2, 4], 'min_samples_split': [2, 5], 'min_samples_leaf': [1, 2], 'bootstrap': [True, False]}

# %%
regressor = RandomForestRegressor()

# %%
from sklearn.model_selection import GridSearchCV
rf_Grid = GridSearchCV(estimator = regressor, param_grid = param_grid, cv = 3, verbose=2)

# %%
rf_Grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 64 candidates, totalling 192 fits
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=  14.7s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=  16.1s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=  15.2s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  31.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  30.0s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  31.0s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time=  44.7s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time=  44.3s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time=  44.5s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=  59.2s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=  59.2s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time= 1.0min
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=  14.9s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=  15.0s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=  15.0s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  30.1s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  30.7s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  29.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time=  44.1s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time=  44.5s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time=  44.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=  59.1s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=  59.4s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=  59.0s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=  15.7s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=  15.0s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=  14.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  29.7s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  29.3s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  29.5s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time=  43.3s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time=  43.9s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time=  44.0s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=  58.1s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=  58.1s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=  58.3s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=20; total time=  14.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=20; total time=  14.5s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=20; total time=  14.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=40; total time=  29.1s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=40; total time=  29.2s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=40; total time=  29.3s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=60; total time=  43.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=60; total time=  43.7s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=60; total time=  44.1s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time= 1.0min
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=  59.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=  59.2s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=  28.7s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=  28.8s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=  29.1s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  58.0s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  57.9s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=40; total time=  58.5s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time= 1.4min
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time= 1.5min
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=60; total time= 1.4min
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time= 1.9min
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time= 1.9min
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time= 1.9min
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=  28.2s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=  28.2s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=  28.2s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  56.5s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  56.4s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=40; total time=  57.5s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time= 1.4min
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time= 1.4min
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=60; total time= 1.4min
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time= 1.9min
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time= 1.9min
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time= 1.9min
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=  29.1s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=  28.7s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=20; total time=  28.5s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  56.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  57.0s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=40; total time=  57.0s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=2, min_samples_split=2, n_estimators=60; total time= 1.4min

# %%
rf_Grid.best_params_

# %%
# Initialize the RandomForestRegressor with the best parameters
#best_estimator = rf_Grid.best_estimator_
regressor = RandomForestRegressor(bootstrap=True, max_depth=4, min_samples_leaf=2, 
                                   min_samples_split=2, n_estimators=80)

# Fit the model to your training data
regressor.fit(X_train, y_train)

# %%
X_test = new_collision_test_scaled.drop(columns=['time_to_tca']).values
y_test = new_collision_test_scaled['time_to_tca'].values

# %%
# Prediction on the testing dataset
# Prediction on the testing dataset
y_test_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
#Evaluating on test set

mae = mean_absolute_error(y_test, y_test_pred)
mse = mean_squared_error(y_test, y_test_pred)
r2 = r2_score(y_test, y_test_pred)
rmse = np.sqrt(mse)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R^2 Score:", r2)

# %%
from sklearn.metrics import explained_variance_score
evs = explained_variance_score(y_test, y_test_pred)

print('The EVS of the test is: %.2f' % evs)

# %%
#Prediction on the training set

y_train_pred = regressor.predict(X_train)

mae = mean_absolute_error(y_train, y_train_pred)
mse = mean_squared_error(y_train, y_train_pred)
r2 = r2_score(y_train, y_train_pred)
rmse = np.sqrt(mse)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R^2 Score:", r2)

# %%
from sklearn.metrics import explained_variance_score
evs = explained_variance_score(y_train, y_train_pred)

print('The EVS of the train is: %.2f' % evs)

# %%
# Create loop throuth x columns
feature_list = [f"feature_{i}" for i in range(X_train.shape[1])]

# Create a pandas Series with feature importances
feature_imp = pd.Series(regressor.feature_importances_, index=feature_list).sort_values(ascending = False)

print("List of important features:", feature_imp)

# %%
plt.rcParams['font.sans-serif'] = 'DejaVu Sans'

# %%
from yellowbrick.regressor import ResidualsPlot

# Instantiate the visualizer with the trained regressor model
visualizer = ResidualsPlot(regressor)

visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
visualizer.poof()
